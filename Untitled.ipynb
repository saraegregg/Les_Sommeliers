# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

import os
import re

wine_df = pd.read_csv('https://raw.githubusercontent.com/saraegregg/Mod20_Group_Challenge/main/data_cleaning/cleaned_wine_data.csv', encoding= 'unicode_escape')
wine_df.head(10)
# Out:
#    Unnamed: 0   country  \
# 0           1  Portugal
# 1           2        US
# 2           3        US
# 3           4        US
# 4           5     Spain
# 5           6     Italy
# 6           7    France
# 7           8   Germany
# 8           9    France
# 9          10        US
#
#                                                                                                                                                                                                                                                              description  \
# 0                                    This is ripe and fruity, a wine that is smooth while still structured. Firm tannins are filled out with juicy red berry fruits and freshened with acidity. It's  already drinkable, although it will certainly be better from 2016.
# ...

# %%
wine_df.description = wine_df.description.apply(lambda x : x.replace(',',''))
wine_df.description = wine_df.description.apply(lambda x : x.replace('.',''))
wine_df.head(10)
# Out:
#    Unnamed: 0   country  \
# 0           1  Portugal
# 1           2        US
# 2           3        US
# 3           4        US
# 4           5     Spain
# 5           6     Italy
# 6           7    France
# 7           8   Germany
# 8           9    France
# 9          10        US
#
#                                                                                                                                                                                                                                                     description  \
# 0                                This is ripe and fruity a wine that is smooth while still structured Firm tannins are filled out with juicy red berry fruits and freshened with acidity It's  already drinkable although it will certainly be better from 2016
# ...

# %%
#Save the cleaned data to a new csv for parsing
wine_df.to_csv("parsing_cleaned_wine_data.csv", index=True)
